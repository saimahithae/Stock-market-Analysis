# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = yf.download('TECHM.NS','2019-10-17', '2020-11-17')
df['Adj Close'].plot(figsize=(10,7))
plt.legend()
plt.grid()
plt.show()
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open        High         Low       Close   Adj Close   Volume
# Date
# 2020-11-09  859.0  877.000000  855.250000  872.750000  872.750000  4297119
# 2020-11-10  872.0  872.000000  819.099976  821.299988  821.299988  6889383
# 2020-11-11  820.0  840.650024  812.450012  837.500000  837.500000  5387431
# 2020-11-12  837.0  848.000000  834.549988  843.250000  843.250000  3150886
# 2020-11-13  838.0  845.700012  833.349976  838.849976  838.849976  2839192

# %%
df.loc['2020-11-13',:]
# Out:
# Open         8.380000e+02
# High         8.457000e+02
# Low          8.333500e+02
# Close        8.388500e+02
# Adj Close    8.388500e+02
# Volume       2.839192e+06
# Name: 2020-11-13 00:00:00, dtype: float64

# %%
df.loc['2020-03-23',:]
# Out:
# Open         5.400000e+02
# High         5.420000e+02
# Low          4.714000e+02
# Close        4.872000e+02
# Adj Close    4.742453e+02
# Volume       2.912669e+06
# Name: 2020-03-23 00:00:00, dtype: float64

# %%
df['daily_pct_change'] = df['Adj Close'].pct_change()
mu = df['daily_pct_change'].iloc[:-252].mean()
sigma = df['daily_pct_change'].iloc[:-252].std()

# Creating the random walk simulation of the probable price path
simulation = {}
simulation['Actual'] = list(df['Adj Close'].iloc[-252:].values)

for sim in range(0,9999): # Taking 25 paths
    simulation["Simulation_"+str(sim)] = [df['Adj Close'].iloc[-252]]
    for days in range(251):
        next_day = simulation["Simulation_"+str(sim)][-1]*np.exp((mu-(sigma**2/2))+sigma*np.random.normal())
        simulation["Simulation_"+str(sim)].append(next_day)

# %%
df['Adj Close'][-252:].plot(figsize=(10,7),grid=True,legend=False)
plt.xlabel('Year')
plt.ylabel('Price')

# Plotting the simulation of random walk

simulation=pd.DataFrame(simulation)
simulation.index=df[-252:].index
simulation.plot(figsize=(10,7),grid=True,legend=False)
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
simulation
# Out:
#                 Actual  Simulation_0  Simulation_1  Simulation_2  \
# Date
# 2019-11-14  728.268860    728.268860    728.268860    728.268860
# 2019-11-15  722.122742    732.440233    735.427708    752.814577
# 2019-11-18  721.978638    747.708831    738.193462    763.425379
# 2019-11-19  732.878479    737.079897    722.123711    742.433074
# 2019-11-20  740.801208    740.696387    727.269735    743.466892
# ...                ...           ...           ...           ...
# 2020-11-09  872.750000   2303.553340   1604.539565   2076.508278
# 2020-11-10  821.299988   2395.403830   1584.774672   2080.254995
# 2020-11-11  837.500000   2462.170461   1570.641910   2067.060338
# 2020-11-12  843.250000   2450.903554   1579.802797   2035.589087
# 2020-11-13  838.849976   2498.480921   1543.223685   2000.885077
#
#             Simulation_3  Simulation_4  Simulation_5  Simulation_6  \
# Date
# 2019-11-14    728.268860    728.268860    728.268860    728.268860
# 2019-11-15    723.633773    707.977139    731.082579    739.339041
# 2019-11-18    756.130843    703.536067    720.026633    736.960887
# 2019-11-19    774.346432    726.471693    726.536029    730.222864
# 2019-11-20    771.926907    731.429857    727.021492    716.727114
# ...                  ...           ...           ...           ...
# 2020-11-09   1625.751563   1185.238030    798.280173   1935.460714
# 2020-11-10   1640.993259   1186.399218    825.772839   1943.620477
# 2020-11-11   1655.905641   1163.501820    837.173696   1951.828769
# 2020-11-12   1699.407204   1199.639230    851.545598   1955.617700
# 2020-11-13   1718.259874   1185.580566    854.110564   1941.875181
#
#             Simulation_7  Simulation_8  ...  Simulation_9989  Simulation_9990  \
# Date                                    ...
# 2019-11-14    728.268860    728.268860  ...       728.268860       728.268860
# 2019-11-15    741.604894    728.662208  ...       743.256431       720.348795
# 2019-11-18    745.991070    720.271556  ...       744.475603       718.627620
# 2019-11-19    744.071134    694.836414  ...       759.569661       709.020073
# 2019-11-20    749.969447    712.636744  ...       773.251980       688.541626
# ...                  ...           ...  ...              ...              ...
# 2020-11-09   1421.649902   1962.780967  ...      1329.888751      1139.499457
# 2020-11-10   1460.264785   1949.670857  ...      1334.417195      1126.594258
# 2020-11-11   1444.031361   1929.735925  ...      1371.834643      1143.874602
# 2020-11-12   1437.210873   1922.951978  ...      1365.097321      1163.768003
# 2020-11-13   1451.262144   1947.947920  ...      1341.887617      1203.079703
#
#             Simulation_9991  Simulation_9992  Simulation_9993  \
# Date
# 2019-11-14       728.268860       728.268860       728.268860
# 2019-11-15       748.654726       723.160755       689.883684
# 2019-11-18       756.381387       722.251421       674.066536
# 2019-11-19       762.097260       729.415995       669.096413
# 2019-11-20       739.871592       734.293245       676.854195
# ...                     ...              ...              ...
# 2020-11-09      1504.421300      1555.493148      2683.931181
# 2020-11-10      1553.232523      1582.605074      2744.150784
# 2020-11-11      1564.385846      1590.395263      2748.356130
# 2020-11-12      1573.230083      1615.992588      2719.889492
# 2020-11-13      1594.272801      1639.994443      2707.566881
#
#             Simulation_9994  Simulation_9995  Simulation_9996  \
# Date
# 2019-11-14       728.268860       728.268860       728.268860
# 2019-11-15       728.107347       717.716580       711.612208
# 2019-11-18       741.888348       735.578357       698.462775
# 2019-11-19       770.823602       743.499064       706.907837
# 2019-11-20       742.813946       741.434275       691.936116
# ...                     ...              ...              ...
# 2020-11-09      1866.935083      1752.737125      1468.983824
# 2020-11-10      1829.092123      1736.401089      1502.996100
# 2020-11-11      1815.579702      1724.235256      1495.220967
# 2020-11-12      1834.946628      1748.638028      1544.577135
# 2020-11-13      1798.740630      1698.876376      1544.248382
#
#             Simulation_9997  Simulation_9998
# Date
# 2019-11-14       728.268860       728.268860
# 2019-11-15       751.570252       744.413911
# 2019-11-18       770.732629       749.662077
# 2019-11-19       781.682081       741.246145
# 2019-11-20       806.869100       727.109203
# ...                     ...              ...
# 2020-11-09      1383.298559       709.173249
# 2020-11-10      1398.706630       719.433771
# 2020-11-11      1388.284365       717.596739
# 2020-11-12      1346.179279       724.992164
# 2020-11-13      1344.695688       708.858506
#
# [252 rows x 10000 columns]

# %%
simulation.to_csv('RandomWalksimulation.csv')

# %%
import numpy as np
accuracy = np.zeros(9999)
from scipy.spatial import distance
for i in range(9999):
    accuracy[i]=distance.cosine(simulation['Actual'], simulation['Simulation_'+str(i)])

# %%
min_ele=accuracy[0]
for i in range(1,len(accuracy)): 
    if accuracy[i]<min_ele: 
        min_ele=accuracy[i] 
        j=i
'Simulation_'+str(j)+' is the closest path for actual path'
# Out:
# 'Simulation_8454 is the closest path for actual path'

# %%
df=simulation[['Actual', 'Simulation_8454']] 
df.plot(figsize=(10,7),grid=True,legend=False)
# Out:
# <AxesSubplot:xlabel='Date'>
